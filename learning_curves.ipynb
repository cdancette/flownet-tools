# %%
from tools import plot_log_file
# %matplotlib inline

# %%
plot_log_file('/home/gpu_user/corentin/flownet2/models/FlowNet2-s/train-logs_solver-2017-10-04-13:51:15')

# %%
plot_log_file('/home/gpu_user/corentin/flownet2/models/FlowNet2-s/full-train-logs_solver-2017-10-04-17:50:17')

# %%
plot_log_file('/home/gpu_user/corentin/flownet2/models/FlowNet2-s/train-all-layers/train-logs_solver-2017-10-11-11:23:31')
